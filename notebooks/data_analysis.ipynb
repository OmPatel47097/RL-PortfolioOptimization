# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('../data/stockdata.csv', index_col=0, header=[0, 1])

# Plot stock prices
data['Adj Close'].plot(figsize=(14, 7))
plt.title('Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(data.columns)
plt.show()

# %%
data.head()
# Out:
# Price      Adj Close                                               Close  \
# Ticker          AAPL       GOOG       MSFT      NFLX      NVDA      AAPL
# Date
# 2010-01-04  6.461977  15.592496  23.389399  7.640000  0.423988  7.643214
# 2010-01-05  6.473148  15.523831  23.396957  7.358571  0.430180  7.656429
# 2010-01-06  6.370184  15.132495  23.253372  7.617143  0.432931  7.534643
# 2010-01-07  6.358407  14.780218  23.011549  7.485714  0.424447  7.520714
# 2010-01-08  6.400681  14.977255  23.170237  7.614286  0.425364  7.570714
#
# Price                                                ...      Open             \
# Ticker           GOOG       MSFT      NFLX     NVDA  ...      AAPL       GOOG
# Date                                                 ...
# 2010-01-04  15.610239  30.950001  7.640000  0.46225  ...  7.622500  15.615220
# 2010-01-05  15.541497  30.959999  7.358571  0.46900  ...  7.664286  15.620949
# 2010-01-06  15.149715  30.770000  7.617143  0.47200  ...  7.656429  15.588072
# ...

# %%
data.describe()
# Out:
# Price     Adj Close                                                      \
# Ticker         AAPL         GOOG         MSFT         NFLX         NVDA
# count   3522.000000  3522.000000  3522.000000  3522.000000  3522.000000
# mean      57.768186    53.940715   109.582410   202.620592     7.266404
# std       55.706711    39.498183   102.282455   180.617738    10.889700
# min        5.798901    10.848695    17.549170     7.018571     0.203624
# 25%       17.005855    21.806917    27.321404    37.636785     0.390796
# 50%       29.137094    39.827679    57.003345   128.639999     2.438994
# 75%       89.074627    73.628214   194.286983   351.237495     9.500883
# max      197.589523   150.537689   381.305847   691.690002    50.398064
#
# Price         Close                                                      ...  \
# Ticker         AAPL         GOOG         MSFT         NFLX         NVDA  ...
# count   3522.000000  3522.000000  3522.000000  3522.000000  3522.000000  ...
# ...

# %%
data.dtypes
# Out:
# Price      Ticker
# Adj Close  AAPL      float64
#            GOOG      float64
#            MSFT      float64
#            NFLX      float64
#            NVDA      float64
# Close      AAPL      float64
#            GOOG      float64
#            MSFT      float64
#            NFLX      float64
#            NVDA      float64
# High       AAPL      float64
#            GOOG      float64
#            MSFT      float64
#            NFLX      float64
#            NVDA      float64
# Low        AAPL      float64
#            GOOG      float64
#            MSFT      float64
#            NFLX      float64
#            NVDA      float64
# Open       AAPL      float64
#            GOOG      float64
#            MSFT      float64
#            NFLX      float64
#            NVDA      float64
# Volume     AAPL        int64
#            GOOG        int64
#            MSFT        int64
#            NFLX        int64
#            NVDA        int64
# dtype: object

# %%
data['Adj Close'].columns
# Out:
# Index(['AAPL', 'GOOG', 'MSFT', 'NFLX', 'NVDA'], dtype='object', name='Ticker')
